# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from time import time 
import sys
import csv
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
from bs4 import BeautifulSoup
from sklearn import preprocessing
import pickle
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\SANDRA\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\SANDRA\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\SANDRA\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
df0 = pd.read_csv('QueryResults.csv')
df1 = pd.read_csv('QueryResults (1).csv')
df2 = pd.read_csv('QueryResults (2).csv')
df3 = pd.read_csv('QueryResults (3).csv')
df4 = pd.read_csv('QueryResults (4).csv')
df5 = pd.read_csv('QueryResults (5).csv')
df6 = pd.read_csv('QueryResults (6).csv')
df7 = pd.read_csv('QueryResults (7).csv')
df8 = pd.read_csv('QueryResults (8).csv')
df9 = pd.read_csv('QueryResults (9).csv')
df10 = pd.read_csv('QueryResults (10).csv')
Liste = [df0,df1,df2,df3,df4,df5,df6,df7,df8,df9,df10]

# %%
df_tot = pd.concat(Liste,axis=0,ignore_index=True)
print(df_tot.shape)
print(df_tot.columns)
# Out:
# (344533, 23)
# Index(['Id', 'PostTypeId', 'AcceptedAnswerId', 'ParentId', 'CreationDate',
#        'DeletionDate', 'Score', 'ViewCount', 'Body', 'OwnerUserId',
#        'OwnerDisplayName', 'LastEditorUserId', 'LastEditorDisplayName',
#        'LastEditDate', 'LastActivityDate', 'Title', 'Tags', 'AnswerCount',
#        'CommentCount', 'FavoriteCount', 'ClosedDate', 'CommunityOwnedDate',
#        'ContentLicense'],
#       dtype='object')

# %%
x = set(df_tot.columns)-set(['Id','AcceptedAnswerId','Score','ViewCount','Body','Title','Tags'])
df_tot.drop(x,axis=1,inplace=True)

# %%
def url_remover(text):
    soup = BeautifulSoup(text)
    x = soup.find_all('a')
    [item.decompose() for item in x]
    cleared_text = soup.get_text()
    return(cleared_text)

# %%
compteur_mots={}
def word_counter(string):
    tokenizer = nltk.RegexpTokenizer(r'\w+')
    word_list =tokenizer.tokenize(string)
    for character in word_list:
        if character in compteur_mots:
            compteur_mots[character]+=1
        else:
            compteur_mots[character]=1

# %%
df_tot['Body']=df_tot['Body'].apply(url_remover)
body_and_title = test1=df_tot['Body']+df_tot['Title']

# %%
body_and_title.apply(word_counter)
# Out:
# 0         None
# 1         None
# 2         None
# 3         None
# 4         None
#           ...
# 344528    None
# 344529    None
# 344530    None
# 344531    None
# 344532    None
# Length: 344533, dtype: object

# %%
word_list = pd.Series(compteur_mots.values(),index=compteur_mots.keys())

# %%
compteur_mots
# Out:
# {'please': 15099,
#  'help': 51319,
#  'I': 1626348,
#  'have': 316841,
#  'this': 579636,
#  'error': 204312,
#  'in': 870557,
#  'android': 148386,
#  'studio': 4359,
#  'Could': 13630,
#  'not': 337681,
#  'find': 65334,
#  'com': 151382,
#  'tools': 16647,
#  'lint': 2559,
#  'gradle': 37718,
#  '26': 16386,
#  '1': 770408,
#  '4': 201140,
#  'Searched': 307,
#  'the': 2092757,
#  'following': 94300,
#  'locations': 2558,
#  'file': 161898,
#  'C': 103529,
#  'Users': 45341,
#  'samir': 13,
#  'AppData': 8314,
#  'Local': 8578,
#  'Android': 30397,
#  'Sdk': 1473,
#  'extras': 930,
#  'm2repository': 71,
#  'pom': 3017,
#  'jar': 36152,
#  'google': 39012,
#  'https': 55771,
#  'jcenter': 1458,
#  'bintray': 447,
#  'Desktop': 6917,
#  'webviewapp': 4,
#  '2': 449127,
#  '0': 940938,
#  'mobile': 5020,
#  'libs': 6161,
#  'Required': 2465,
#  'by': 128649,
#  'project': 69900,
#  'here': 62349,
#  'want': 119105,
#  'that': 424451,
#  'no': 83612,
#  'one': 96174,
#  'can': 235214,
#  'copy': 14783,
#  'sound': 2311,
#  'of': 619275,
#  'my': 296478,
#  'app': 175340,
#  'as': 268235,
#  'it': 491634,
#  's': 203408,
#  'copyrighted': 7,
#  'For': 38173,
#  'am': 182409,
#  'thinking': 3689,
#  'to': 1568594,
#  'store': 22108,
#  'ogg': 152,
#  'wind': 184,
#  'and': 739267,
#  'extract': 6764,
#  'at': 311078,
#  'runtime': 17275,
#  'How': 137551,
#  'we': 58452,
#  'do': 151638,
#  'Thank': 11410,
#  'you': 90720,
#  'data': 218392,
#  'from': 333356,
#  'WIND': 7,
#  'wnd': 70,
#  'understand': 25733,
#  'been': 36037,
#  'charges': 142,
#  'for': 459772,
#  'every': 23909,
#  'read': 38572,
#  'write': 27786,
#  'delete': 13589,
#  'operation': 9165,
#  'but': 275094,
#  'question': 36508,
#  'are': 154932,
#  'these': 35717,
#  'also': 61176,
#  'being': 25344,
#  'counted': 326,
#  'firebase': 20568,
#  'console': 57762,
#  'Sometimes': 1268,
#  'just': 64708,
#  'wanna': 760,
#  'see': 56221,
#  'through': 27025,
#  'when': 159461,
#  'click': 24129,
#  'collection': 10995,
#  'will': 84411,
#  'automatically': 8868,
#  'display': 27226,
#  'documents': 4486,
#  'sub': 8526,
#  'Are': 4782,
#  'gonna': 290,
#  'get': 190084,
#  'charged': 146,
#  'activity': 8383,
#  'too': 14200,
#  'Firestore': 3001,
#  'Pricing': 88,
#  'Does': 14206,
#  'The': 185083,
#  'CRUD': 442,
#  'In': 65602,
#  'Firebase': 10054,
#  'Console': 7850,
#  'Matter': 43,
#  'include': 45928,
#  'iostream': 3623,
#  'struct': 22926,
#  'A': 80377,
#  'void': 65720,
#  'f': 40598,
#  'const': 126611,
#  'std': 64922,
#  'cout': 11340,
#  'endl': 6791,
#  'B': 40971,
#  'int': 106446,
#  'main': 73224,
#  'output': 56943,
#  'is': 830437,
#  'Note': 11724,
#  'doesn': 47767,
#  't': 238134,
#  'exist': 11198,
#  'To': 17823,
#  'me': 79659,
#  'a': 1069082,
#  'temporary': 2393,
#  'object': 63806,
#  'calls': 10357,
#  'should': 71275,
#  'be': 247909,
#  'chosen': 1231,
#  'or': 166855,
#  'compiler': 17479,
#  'raised': 1435,
#  'Why': 26651,
#  'such': 26941,
#  'case': 47560,
#  'called': 25523,
#  'm': 185649,
#  'currently': 14317,
#  'leaning': 64,
#  'HTTP': 10303,
#  'Client': 7657,
#  'Java9': 15,
#  '10': 139009,
#  'Java': 18959,
#  '9': 77842,
#  'does': 75396,
#  'HttpRequest': 713,
#  'BodyProcessor': 3,
#  'interface': 15371,
#  'while': 40083,
#  'instead': 28257,
#  'BodyPublisher': 9,
#  'Both': 3292,
#  'interfaces': 1999,
#  'similar': 17185,
#  'change': 42699,
#  'Interface': 1050,
#  'name': 178432,
#  'think': 20275,
#  'backward': 1047,
#  'compatibility': 1344,
#  'ignored': 2646,
#  'Where': 6894,
#  'Java10': 7,
#  'THE': 1460,
#  'PROBLEM': 321,
#  'When': 49190,
#  'grab': 1056,
#  'resize': 3079,
#  'border': 13407,
#  'Windows': 18735,
#  'especially': 1886,
#  'top': 24723,
#  'left': 23346,
#  'borders': 503,
#  'window': 24668,
#  'contents': 5090,
#  'live': 3734,
#  'drag': 2668,
#  'they': 33263,
#  'hideous': 22,
#  'manner': 1055,
#  'looks': 24343,
#  'like': 168849,
#  'blatant': 5,
#  'bug': 7173,
#  'even': 29331,
#  'most': 18545,
#  'novice': 258,
#  'user': 92169,
#  'opposite': 805,
#  'edge': 3505,
#  'dragging': 742,
#  'jitter': 179,
#  'flicker': 159,
#  'jump': 1267,
#  'back': 19957,
#  'forth': 537,
#  'wildly': 67,
#  'Depending': 270,
#  'on': 313673,
#  'situation': 4239,
#  'phenomenon': 103,
#  'may': 17517,
#  'look': 15623,
#  'seem': 18199,
#  'walk': 738,
#  'off': 9699,
#  'snap': 1355,
#  'slow': 4825,
#  'down': 13057,
#  'stop': 9497,
#  'pull': 4865,
#  'into': 61415,
#  'intermittently': 154,
#  'displaced': 32,
#  'varying': 805,
#  'colors': 5366,
#  'often': 2513,
#  'black': 8186,
#  'white': 11541,
#  'seriously': 111,
#  'ugly': 1183,
#  'double': 16846,
#  'image': 66163,
#  'with': 408466,
#  'two': 48856,
#  'overlapping': 1013,
#  'copies': 966,
#  'content': 38831,
#  'distance': 4539,
#  'proportional': 125,
#  'how': 110986,
#  'much': 15661,
#  'fast': 3253,
#  'stops': 2299,
#  'soon': 2898,
#  'during': 9827,
#  'makes': 9205,
#  'amateurish': 3,
#  'unprofessional': 9,
#  'It': 55331,
#  'an': 211552,
#  'understatement': 5,
#  'say': 15080,
#  'problem': 69420,
#  'has': 86103,
#  'driven': 305,
#  'thousands': 925,
#  'developers': 1697,
#  'crazy': 490,
#  'Here': 48094,
#  'example': 78901,
#  'pictures': 837,
#  'kindly': 346,
#  'prepared': 586,
#  'Jitter': 9,
#  'Border': 464,
#  'Another': 2805,
#  'showing': 8570,
#  'evil': 94,
#  'note': 10214,
#  'quick': 1733,
#  'flash': 887,
#  'video': 13652,
#  'Task': 13427,
#  'Manager': 2539,
#  'QUESTION': 355,
#  'Any': 32107,
#  'developer': 4002,
#  'who': 4433,
#  'experienced': 887,
#  'quickly': 1521,
#  'finds': 1074,
#  'there': 132737,
#  'least': 7519,
#  '30': 33479,
#  'Stack': 4201,
#  'Overflow': 778,
#  'questions': 9468,
#  'some': 101360,
#  'recent': 9203,
#  'dating': 23,
#  '2008': 959,
#  'full': 12575,
#  'promising': 383,
#  'sounding': 24,
#  'answers': 6107,
#  'rarely': 225,
#  'work': 77141,
#  'reality': 563,
#  'many': 19224,
#  'causes': 4423,
#  'existing': 9200,
#  'never': 10419,
#  'make': 56032,
#  'wider': 250,
#  'context': 51446,
#  'clear': 9911,
#  'This': 97615,
#  'seeks': 54,
#  'answer': 16017,
#  'what': 85950,
#  'likely': 2657,
#  'kind': 12331,
#  'jumping': 267,
#  'tell': 8542,
#  'which': 130799,
#  'cause': 7356,
#  'seeing': 3039,
#  'specific': 19661,
#  'particular': 6388,
#  'graphics': 2570,
#  'drivers': 763,
#  'general': 4289,
#  'fix': 19697,
#  'each': 53048,
#  'meant': 1333,
#  'canonical': 440,
#  'Q': 3459,
#  'explain': 7140,
#  'all': 118613,
#  'different': 44333,
#  'so': 115260,
#  'users': 22387,
#  'identify': 2118,
#  'causing': 4579,
#  'their': 16062,
#  'solve': 15064,
#  'As': 26278,
#  'permutations': 515,
#  'above': 32593,
#  'native': 27976,
#  'managed': 5565,
#  'dialog': 5759,
#  'XP': 117,
#  'boil': 60,
#  'only': 90192,
#  'root': 28209,
#  'identifying': 287,
#  'tricky': 509,
#  'part': 19413,
#  'SCOPE': 78,
#  'OF': 1048,
#  'THIS': 1087,
#  'scope': 12994,
#  'happens': 9911,
#  'both': 30291,
#  'Win32': 655,
#  'NET': 13710,
#  'WPF': 965,
#  'Forms': 1996,
#  'apps': 8371,
#  'normal': 9013,
#  'windows': 8836,
#  'Dialog': 1086,
#  'versions': 13198,
#  'including': 5655,
#  'Vista': 19,
#  '7': 117913,
#  '8': 118795,
#  'below': 48243,
#  'dark': 3233,
#  'truth': 670,
#  'multiple': 28287,
#  'NOT': 8316,
#  'IN': 3099,
#  'If': 56484,
#  'your': 27489,
#  'more': 50067,
#  'child': 27360,
#  'HWNDs': 1,
#  'info': 24761,
#  'useful': 3927,
#  'since': 20911,
#  'jerk': 18,
#  'BitBlts': 1,
#  'describe': 3657,
#  'applied': 4170,
#  'along': 4671,
#  'parent': 23024,
#  'additional': 6801,
#  'handle': 13992,
#  'beyond': 1043,
#  'need': 72597,
#  'move': 11156,
#  'atomically': 149,
#  'sync': 4149,
#  'task': 23811,
#  'probably': 5499,
#  'BeginDeferWindowPos': 1,
#  'DeferWindowPos': 1,
#  'EndDeferWindowPos': 1,
#  'out': 74912,
#  'about': 42694,
#  'them': 38461,
#  'assumes': 405,
#  'if': 271836,
#  'draws': 336,
#  'using': 226326,
#  'GDI': 98,
#  'DirectX': 91,
#  'OpenGL': 1171,
#  'then': 82309,
#  'already': 24800,
#  'implemented': 6767,
#  'WM_ERASEBKGND': 6,
#  'handler': 9719,
#  'wndproc': 1,
#  'simply': 8379,
#  'returns': 21479,
#  'arcane': 19,
#  'remnant': 5,
#  '3': 312953,
#  'comes': 6295,
#  'before': 29879,
#  'WM_PAINT': 9,
#  'give': 11512,
#  'chance': 765,
#  'erase': 516,
#  'background': 29831,
#  'draw': 5711,
#  'uh': 50,
#  'huh': 35,
#  'let': 66238,
#  'message': 54839,
#  'go': 26941,
#  'DefWindowProc': 12,
#  'entire': 5957,
#  'painted': 85,
#  'solid': 5023,
#  'color': 49403,
#  'usually': 2600,
#  'redraw': 229,
#  'redraws': 29,
#  'happen': 6155,
#  'resizing': 550,
#  'result': 61552,
#  'gross': 270,
#  'type': 148638,
#  'talking': 1051,
#  'Intercepting': 15,
#  'fixes': 1031,
#  'immediately': 3269,
#  'primarily': 252,
#  'mouse': 3457,
#  'However': 41347,
#  'written': 8683,
#  'applies': 1101,
#  'artifacts': 2462,
#  'manually': 9638,
#  'time': 82992,
#  'SetWindowPos': 37,
#  'These': 4698,
#  'less': 6998,
#  'visible': 6204,
#  'though': 11081,
#  'because': 46338,
#  'flick': 40,
#  'screen': 18842,
#  'instant': 446,
#  'rather': 7905,
#  'than': 30839,
#  'over': 19511,
#  'long': 20674,
#  'period': 2661,
#  'drawing': 1330,
#  'code': 199210,
#  'faster': 4166,
#  'doing': 26303,
#  'solution': 33107,
#  'cases': 7753,
#  'really': 17795,
#  'take': 13248,
#  'huge': 2076,
#  'amounts': 368,
#  'redisplay': 20,
#  'its': 32189,
#  'consider': 2996,
#  'optimizing': 293,
#  'switching': 1514,
#  'lower': 3887,
#  'quality': 1237,
#  'mode': 18683,
#  'intercepting': 95,
#  'WM_ENTERSIZEMOVE': 1,
#  'WM_EXITSIZEMOVE': 1,
#  'messages': 11810,
#  'detect': 4696,
#  'fails': 13048,
#  'e': 74027,
#  'g': 34741,
#  'hangs': 1063,
#  'GLFW': 165,
#  'other': 63191,
#  'library': 37430,
#  'Microsoft': 25670,
#  'nested': 9793,
#  'modal': 6248,
#  'event': 38859,
#  'loop': 22960,
#  'inside': 30325,
#  'WM_SYSCOMMAND': 12,
#  'smooth': 1107,
#  'Win': 371,
#  'bg': 2495,
#  'bitblt': 2,
#  'DWM': 7,
#  'trying': 86338,
#  'between': 30295,
#  'iOS': 15833,
#  'device': 18683,
#  'front': 4440,
#  'facing': 3996,
#  'camera': 6537,
#  'face': 2459,
#  'real': 8667,
#  'world': 6348,
#  'So': 56370,
#  'far': 17155,
#  'tried': 88602,
#  'ARKit': 253,
#  'SceneKit': 214,
#  'ARFaceAnchor': 21,
#  'able': 37338,
#  'works': 56624,
#  'close': 14000,
#  'proximity': 71,
#  'up': 54813,
#  '88': 3376,
#  'cm': 1035,
#  'My': 56560,
#  'application': 62746,
#  'requires': 9285,
#  'detection': 1768,
#  '200': 16441,
#  'cms': 268,
#  'assuming': 2080,
#  'could': 45002,
#  'achieved': 1387,
#  'without': 42815,
#  'use': 163637,
#  'trueDepth': 1,
#  'used': 47818,
#  'Can': 27431,
#  'put': 18616,
#  'right': 33682,
#  'direction': 6363,
#  'Find': 2371,
#  'Device': 2280,
#  'Camera': 1162,
#  'Preferences': 367,
#  'Editor': 1412,
#  'Code': 18960,
#  'Style': 1410,
#  'XML': 4099,
#  'select': 26316,
#  'Use': 7812,
#  'custom': 26851,
#  'formatting': 1945,
#  'settings': 15487,
#  'files': 51843,
#  'again': 16321,
#  'everytime': 1006,
#  'create': 67367,
#  'new': 182938,
#  'Studio': 15950,
#  'macos': 358,
#  '14': 41400,
#  'remember': 1255,
#  'style': 43799,
#  'table': 46861,
#  'head': 11924,
#  'dynamic': 11523,
#  'columns': 24436,
#  'search': 17238,
#  'sorting': 1713,
#  'functions': 23487,
#  'disable': 9036,
#  'function': 164967,
#  'thead': 1558,
#  'tr': 12335,
#  'class': 236874,
#  'th': 10972,
#  'ngFor': 1702,
#  'colName': 113,
#  'reportColHeader': 3,
#  'i': 213709,
#  'index': 59360,
#  'sortIcons': 1,
#  'toggleSort': 1,
#  'constructor': 16505,
#  'passing': 5742,
#  'values': 53191,
#  'array': 60200,
#  'Not': 9542,
#  'server': 67619,
#  'static': 39536,
#  'ID': 20294,
#  'LABEL': 768,
#  'More': 2603,
#  'column': 36938,
#  'last': 26058,
#  'nth': 1394,
#  'assumption': 814,
#  'possible': 38404,
#  'reportColHeaderOptions': 1,
#  'true': 106280,
#  'false': 69109,
#  'show': 32303,
#  'hide': 5050,
#  'pass': 20475,
#  'follow': 4992,
#  'reportColHeaderOpions': 1,
#  'same': 80607,
#  'order': 26640,
#  'Angular6': 35,
#  'single': 20058,
#  'row': 36606,
#  'map': 35754,
#  'API': 39636,
#  'v3': 4733,
#  'angular': 27947,
#  'however': 13918,
#  'add': 70823,
#  'creates': 5021,
#  'hidden': 8653,
#  'div': 131743,
#  'position': 24497,
#  'absolute': 5029,
#  '0px': 3304,
#  '2px': 1679,
#  'height': 37820,
#  '1px': 3684,
#  'overflow': 4991,
#  'visibility': 2415,
#  'width': 47180,
#  'span': 23433,
#  'font': 19012,
#  'size': 50715,
#  '300px': 748,
#  'auto': 21344,
#  'margin': 11731,
#  'padding': 15143,
#  'family': 4731,
#  'Roboto': 540,
#  'Arial': 668,
#  'sans': 1356,
#  'serif': 1467,
#  'BESbswy': 2,
#  'element': 29445,
#  'bottom': 13123,
#  'body': 35154,
#  'didn': 13777,
#  'realize': 1045,
#  'until': 9666,
#  'felt': 179,
#  'fps': 807,
#  'reduced': 835,
#  'working': 53331,
#  'creating': 16918,
#  'polygon': 1623,
#  'manager': 6225,
#  'etc': 21986,
#  'after': 51794,
#  'several': 9376,
#  'hours': 5176,
#  'debugging': 4267,
#  'realized': 1193,
#  'useless': 775,
#  'triggered': 3284,
#  'second': 23721,
#  'performance': 7958,
#  'issue': 43042,
#  'checked': 10111,
#  'ngAfterViewChecked': 20,
#  'component': 50399,
#  'loaded': 8771,
#  'completely': 4925,
#  'continuously': 644,
#  'removed': 7070,
#  'dom': 7820,
#  'everything': 13557,
#  'found': 56546,
#  'related': 10307,
#  'couldn': 7301,
#  'any': 105704,
#  'acceptable': 881,
#  'value': 148930,
#  'reduce': 4262,
#  'Source': 8000,
#  'database': 29008,
#  'PostgreSQL': 2275,
#  'hosted': 3903,
#  'Azure': 14171,
#  'VM': 3389,
#  'D16s_v3': 1,
#  'Destination': 573,
#  'SQL': 11741,
#  'Server': 14155,
#  'edition': 541,
#  'D4s_v3': 1,
#  'around': 14675,
#  '1TB': 40,
#  'empty': 17075,
#  'schema': 9871,
#  'identical': 2329,
#  'source': 31510,
#  'Throughput': 56,
#  '1mb': 50,
#  'Nothing': 2835,
#  'helps': 1746,
#  've': 65735,
#  'selected': 10066,
#  'max': 16538,
#  'DIU': 2,
#  'keys': 11392,
#  'indexes': 2015,
#  'point': 21441,
#  'Batch': 807,
#  '10000': 3515,
#  'See': 5653,
#  'screenshot': 3729,
#  'Data': 17445,
#  'Factory': 1563,
#  'simple': 25687,
#  'game': 4750,
#  'runs': 10763,
#  'browser': 19195,
#  'having': 19763,
#  'hard': 4797,
#  'modeling': 198,
#  'given': 15985,
#  'combination': 2756,
#  'restrictions': 556,
#  'imposed': 69,
#  'rust': 1126,
#  'wasm': 1081,
#  'bindgen': 116,
#  'typical': 803,
#  'follows': 10029,
#  'pattern': 9476,
#  'mainLoop': 40,
#  'update': 32913,
#  'requestAnimationFrame': 341,
#  'were': 11207,
#  'model': 55321,
#  'exact': 6411,
#  'would': 105141,
#  'main_loop': 22,
#  'Closure': 494,
#  'wrap': 5375,
#  'Box': 2695,
#  'request_animation_frame': 1,
#  'as_ref': 188,
#  'unchecked_ref': 1,
#  'legal': 675,
#  'FnMut': 88,
#  'Unlike': 207,
#  'javascript': 9037,
#  'unable': 8450,
#  'reference': 19028,
#  'within': 19352,
#  'itself': 9012,
#  'An': 7439,
#  'alternative': 3475,
#  'approach': 12314,
#  'someone': 13384,
#  'suggested': 3840,
#  'illustrated': 172,
#  'At': 6170,
#  'high': 4370,
#  'level': 16685,
#  'involves': 835,
#  'exporting': 740,
#  'contains': 18710,
#  'state': 47457,
#  'includes': 5260,
#  'public': 123477,
#  'tick': 1328,
#  'render': 18960,
#  'gamestate': 28,
#  'lifetime': 1697,
#  'parameters': 15053,
#  'effectively': 865,
#  'wraps': 655,
#  'World': 3108,
#  'Dispatcher': 372,
#  'latter': 1125,
#  'Ultimately': 300,
#  'means': 9106,
#  'export': 33408,
#  'wasm_bindgen': 91,
#  'finding': 3386,
#  'ways': 5659,
#  'looking': 15895,
#  'suggestions': 6077,
#  'lifetimes': 205,
#  'Google': 19331,
#  'Cloud': 6563,
#  'Translate': 240,
#  'generated': 13829,
#  'JSON': 16878,
#  'service': 40790,
#  'account': 11592,
#  'set': 87693,
#  'GOOGLE_APPLICATION_CREDENTIALS': 181,
#  'where': 60434,
#  'saved': 4309,
#  'program': 18871,
#  'import': 180141,
#  'cloud': 10421,
#  'translate': 4175,
#  'TranslateOptions': 7,
#  'getDefaultInstance': 77,
#  'getService': 197,
#  'Translation': 254,
#  'translation': 1602,
#  'But': 70481,
#  'TranslateException': 1,
#  'Your': 3263,
#  'authenticated': 2148,
#  'end': 44217,
#  'credentials': 6889,
#  'SDK': 7683,
#  'Shell': 887,
#  'supported': 7225,
#  'googleapis': 3352,
#  'We': 17238,
#  'recommend': 918,
#  'applications': 3664,
#  'accounts': 2560,
#  'information': 18084,
#  'docs': 10430,
#  'authentication': 8845,
#  'spi': 940,
#  'v2': 6579,
#  'HttpTranslateRpc': 6,
#  'java': 216320,
#  '61': 4956,
#  '144': 1642,
#  'TranslateImpl': 8,
#  'call': 55059,
#  '113': 1521,
#  '110': 2766,
#  'api': 41402,
#  'gax': 179,
#  'retrying': 369,
#  'DirectRetryingExecutor': 12,
#  'submit': 7747,
#  '89': 3460,
#  'RetryHelper': 20,
#  'run': 105966,
#  '74': 4123,
#  'runWithRetries': 11,
#  '51': 7884,
#  '124': 1678,
#  'websockets': 637,
#  'Messenger': 190,
#  'onMessage': 511,
#  '31': 16312,
#  'org': 145601,
#  'java_websocket': 5,
#  'WebSocketServer': 43,
#  'onWebsocketMessage': 1,
#  '569': 293,
#  'drafts': 42,
#  'Draft_6455': 2,
#  'processFrame': 5,
#  '709': 232,
#  'WebSocketImpl': 4,
#  'decodeFrames': 1,
#  '367': 425,
#  'decode': 3658,
#  '212': 1159,
#  'WebSocketWorker': 1,
#  '925': 254,
#  'Caused': 5490,
#  'client': 43227,
#  'json': 52244,
#  'GoogleJsonResponseException': 24,
#  '403': 2514,
#  'Forbidden': 701,
#  'errors': 24872,
#  'domain': 9390,
#  'usageLimits': 14,
#  'reason': 13946,
#  'rateLimitExceeded': 4,
#  'status': 27480,
#  'PERMISSION_DENIED': 132,
#  '146': 1114,
#  'services': 21471,
#  'AbstractGoogleJsonClientRequest': 16,
#  'newExceptionOnError': 8,
#  '40': 16535,
#  'AbstractGoogleClientRequest': 66,
#  'interceptResponse': 4,
#  '321': 882,
#  'http': 56539,
#  'execute': 28579,
#  '1067': 70,
#  'executeUnparsed': 20,
#  '419': 412,
#  '352': 484,
#  '469': 410,
#  '130': 1857,
#  '13': 42861,
#  'service_account': 138,
#  'project_id': 449,
#  'ecstatic': 5,
#  'motif': 23,
#  '220300': 3,
#  'private_key_id': 34,
#  'keyid': 31,
#  'private_key': 234,
#  'somekey': 14,
#  'client_email': 70,
#  'kokosole': 2,
#  'iam': 1447,
#  'gserviceaccount': 290,
#  'client_id': 1307,
#  '100208235593900994013': 1,
#  'auth_uri': 39,
#  'o': 23681,
#  'oauth2': 2141,
#  'auth': 16712,
#  'token_uri': 46,
#  'token': 26994,
#  'auth_provider_x509_cert_url': 26,
#  'www': 18126,
#  'v1': 14135,
#  'certs': 1288,
#  'client_x509_cert_url': 19,
#  'robot': 568,
#  'metadata': 9495,
#  'x509': 499,
#  '40ecstatic': 1,
#  'anyone': 20181,
#  'going': 11831,
#  'installed': 19715,
#  'connect': 21199,
#  'numpy': 14784,
#  'X': 27550,
#  '5': 202456,
#  '6': 127034,
#  'replace': 13827,
#  'indices': 3294,
#  'respectively': 1326,
#  'words': 7524,
#  'replaced': 2596,
#  'original': 9919,
#  'singular': 256,
#  'Question': 5136,
#  'Is': 77177,
#  'ish': 299,
#  'way': 99244,
#  'loops': 3671,
#  'usage': 6219,
#  'python': 44120,
#  'lists': 6462,
#  'Thanks': 28033,
#  'equivalent': 4545,
#  'replacing': 1611,
#  'place': 9154,
#  'another': 31998,
#  'Its': 1242,
#  'Replace': 1554,
#  'elements': 16657,
#  'title': 39891,
#  'says': 10478,
#  'cannot': 30342,
#  'checking': 7402,
#  ...}

# %%
list_stop_words = set(nltk.corpus.stopwords.words('english'))
for word in word_list.index:
    if word.lower() in list_stop_words:
        word_list.drop(word,inplace=True)

# %%
word_list.nlargest(60)
# Out:
# 0            940938
# 1            770408
# 2            449127
# 3            312953
# class        236874
# using        226326
# data         218392
# java         216320
# error        204312
# 5            202456
# 4            201140
# code         199210
# return       198604
# get          190084
# new          182938
# import       180141
# name         178432
# app          175340
# like         168849
# function     164967
# use          163637
# file         161898
# com          151382
# value        148930
# type         148638
# android      148386
# org          145601
# id           142880
# 10           139009
# x            135981
# div          131743
# 6            127034
# const        126611
# public       123477
# js           120728
# want         119105
# 8            118795
# self         118367
# 7            117913
# var          108147
# int          106446
# true         106280
# run          105966
# would        105141
# C            103529
# string       101490
# way           99244
# c             96737
# one           96174
# test          96167
# build         95132
# following     94300
# version       93014
# user          92169
# line          91728
# tried         88602
# lib           87938
# set           87693
# trying        86338
# String        85241
# dtype: int64

# %%
compteur_mots_bis={}
def word_counter_bis(string):
    tokenizer = nltk.RegexpTokenizer(r'[a-zA-Z]{2,}')
    word_list =tokenizer.tokenize(string)
    for character in word_list:
        if character in compteur_mots_bis:
            compteur_mots_bis[character]+=1
        else:
            compteur_mots_bis[character]=1

# %%
body_and_title.apply(word_counter_bis)
# Out:
# 0         None
# 1         None
# 2         None
# 3         None
# 4         None
#           ...
# 344528    None
# 344529    None
# 344530    None
# 344531    None
# 344532    None
# Length: 344533, dtype: object

# %%
word_list_bis = pd.Series(compteur_mots_bis.values(),index=compteur_mots_bis.keys())

# %%
for word in word_list_bis.index:
    if word.lower() in list_stop_words:
        word_list_bis.drop(word,inplace=True)

# %%
word_list_bis.nlargest(60)
# Out:
# data         244000
# class        243615
# using        226500
# java         218062
# name         215863
# get          213482
# error        210190
# code         205237
# return       201088
# id           193758
# new          192971
# app          184942
# import       182599
# file         180151
# function     170738
# like         169361
# use          166256
# type         164216
# value        161743
# com          152003
# android      149354
# org          146337
# div          132715
# const        127438
# public       125056
# test         123598
# js           121716
# want         119196
# self         118859
# var          114561
# run          112984
# int          112979
# string       109253
# user         108899
# true         108166
# would        105156
# build        101250
# set          101041
# version       99943
# way           99332
# one           98511
# line          96481
# following     94358
# lib           93398
# text          92376
# time          92081
# list          91990
# node          88607
# tried         88602
# trying        86343
# String        86076
# py            82826
# add           82796
# main          82035
# example       81442
# python        79499
# work          78133
# log           77179
# image         76121
# create        74062
# dtype: int64

# %%
pickle_tok_fct = open('df_tot.pickle','wb')
pickle.dump(df_tot,pickle_tok_fct)
pickle_tok_fct.close()
pickle_tok_fct = open('body_and_title.pickle','wb')
pickle.dump(body_and_title,pickle_tok_fct)
pickle_tok_fct.close()
